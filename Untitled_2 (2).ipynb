# %% [markdown]
# # imports

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import json
import time
import plotly.express as px
import tqdm.notebook as tq
import spacy
from wordcloud import WordCloud, STOPWORDS
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
spacy.cli.download("en_core_web_lg")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-eeb20b3ff124> in <module>()
# ----> 1 spacy.cli.download("en_core_web_lg")
#
# /usr/local/lib/python3.7/dist-packages/spacy/cli/download.py in download(model, direct, *pip_args)
#      46         compatibility = get_compatibility()
#      47         version = get_version(model_name, compatibility)
# ---> 48         dl = download_model(dl_tpl.format(m=model_name, v=version), pip_args)
#      49         if dl != 0:  # if download subprocess doesn't return 0, exit
#      50             sys.exit(dl)
#
# /usr/local/lib/python3.7/dist-packages/spacy/cli/download.py in download_model(filename, user_pip_args)
#     133         pip_args.extend(user_pip_args)
#     134     cmd = [sys.executable, "-m", "pip", "install"] + pip_args + [download_url]
# --> 135     return subprocess.call(cmd, env=os.environ.copy())
#
# /usr/lib/python3.7/subprocess.py in call(timeout, *popenargs, **kwargs)
#     339     with Popen(*popenargs, **kwargs) as p:
#     340         try:
# --> 341             return p.wait(timeout=timeout)
#     342         except:  # Including KeyboardInterrupt, wait handled that.
#     343             p.kill()
#
# /usr/lib/python3.7/subprocess.py in wait(self, timeout)
#    1017             endtime = _time() + timeout
#    1018         try:
# -> 1019             return self._wait(timeout=timeout)
#    1020         except KeyboardInterrupt:
#    1021             # https://bugs.python.org/issue25942
#
# /usr/lib/python3.7/subprocess.py in _wait(self, timeout)
#    1651                         if self.returncode is not None:
#    1652                             break  # Another thread waited.
# -> 1653                         (pid, sts) = self._try_wait(0)
#    1654                         # Check the pid and loop as waitpid has been known to
#    1655                         # return 0 even without WNOHANG in odd situations.
#
# /usr/lib/python3.7/subprocess.py in _try_wait(self, wait_flags)
#    1609             """All callers to this function MUST hold self._waitpid_lock."""
#    1610             try:
# -> 1611                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1612             except ChildProcessError:
#    1613                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %% [markdown]
# # Scraping

# %%
def trustpilot_scraper(PATH: str, n_pages):

    #Lists
    body = []
    heading = []
    rating = []
    location = []
    author = []
    date = []

    #Website Load
    page = "{}?page=".format(PATH)

    for page_number in tqdm(range(1, n_pages+1)):
        url = "{x}{y}".format(x = page, y = page_number)
        req = requests.get(url)

        time.sleep(2)
        soup = BeautifulSoup(req.text, 'html.parser')

        #initial reviews
        reviews_raw = soup.find("script", id = "__NEXT_DATA__").string
        reviews_raw = json.loads(reviews_raw)
        rev = reviews_raw["props"]["pageProps"]["reviews"]

        #get reviews into df
        for i in tqdm(range(len(rev))):
            instance = rev[i]
            body_ = GoogleTranslator(source='auto').translate(instance["text"], dest='en')
            heading_ = GoogleTranslator(source='auto').translate(instance["title"], dest='en')
            rating_ = instance["rating"]
            location_ = instance["consumer"]["countryCode"]
            author_ = instance["consumer"]["displayName"]
            date_ = pd.to_datetime(instance["dates"]["publishedDate"]).strftime("%Y-%m-%d")

            #append to the list
            body.append(body_)
            heading.append(heading_)
            rating.append(rating_)
            location.append(location_)
            author.append(author_)
            date.append(date_)

    df = {
    'Date' : date,
    'Author' : author,
    'Body' : body,
    'Heading' : heading,
    'Rating' : rating,
    'Location' : location
    }

    rev_df = pd.DataFrame(df)
    rev_df.sort_values(by = "Date", axis = 0, inplace = True, ignore_index = True)
    rev_df.drop_duplicates(subset=["Body"],keep= 'first', inplace= True)
    rev_df.reset_index(drop = True, inplace = True)

    return rev_df

# %%
df = trustpilot_scraper('https://dk.trustpilot.com/review/www.alka.dk',50)
df

# %% [markdown]
# # Expand data

# %%
def getClasses(rating):
    
    """Function returns if a rating classifies as positive or negative. 
    Neutral is also included"""

    #rating is 2 or less, return negative
    if int(rating) <= 2:
        return 'negative'

    #rating is 3 or less, return neutral
    elif int(rating) == 3:
        return 'neutral'

    #rating is 4 or more, return positive
    else:
        return 'positive'

# %%
#call function to get classes
df['class'] = df['Rating'].map(getClasses)

# %%
#instantiate instance of gender_guesser
detect_gender = gd.Detector()

def getGender(name_string):
    
    """
    Infers gender using gender-guesser 0.4.0 on users
    first name
    
    Hard recode of 'mostly' and 'andy'
    """
    
    #infer gender on users first name
    gender = detect_gender.get_gender(name_string.split(' ')[0])
    
    #recode if mostly female
    if gender == 'mostly_female':
        
        return 'female'
    
    #recode if mostly male
    elif gender == 'mostly_male':
        
        return 'male'
    
    #recode if androgenous
    elif gender == 'andy':
        
        return 'unknown'
    
    else:
        
        return gender

# %%
#call function to get first name
df['gender'] = df['Author'].map(lambda x: getGender(x))

# %%
def getDate(df,date_col):
    
    """
    Extracts various time features from a datetime formatted
    column
    """
    #convert to datetime
    df[date_col] = pd.to_datetime(df[date_col]) 
    #get day of week
    df['day'] = df[date_col].map(lambda x: x.day_name())
    #get day of year
    df['day_of_year'] = df[date_col].map(lambda x: x.dayofyear)
    #get day of year
    df['week_of_year'] = df[date_col].map(lambda x: x.weekofyear)
    #get month year
    df['month_year'] = df[date_col].map(lambda x: x.to_period('M'))
    #get month
    df['month'] = df[date_col].map(lambda x: x.month_name())
    #get quarter
    df['quarter'] = df[date_col].map(lambda x: x.quarter)
    #get year
    df['year'] = df[date_col].map(lambda x: x.year)
    
    return df

# %%
#call function to get date features
df['Body'].fillna("",inplace=True)
df = getDate(df,'Date')
#get length of review
df['review_length'] = df['Body'].map(lambda x: len(x))

# %% [markdown]
# ## save data

# %%
# save dataframe as a pickle file
df.to_pickle('data.pkl')
df
# Out:
#           Date                  Author  \
# 0   2022-01-16                    René
# 1   2022-01-16       Tonni Kristensen.
# 2   2022-01-16                    inga
# 3   2022-01-17             Ib Lorenzen
# 4   2022-01-17             Susann Taha
# ..         ...                     ...
# 977 2022-04-24           Martine Hocke
# 978 2022-04-24          Helle Emmerich
# 979 2022-04-24  Susanne Opperby Madsen
# 980 2022-04-24    Torben Juel Petersen
# 981 2022-04-24           Karina Larsen
#
#                                                   Body  \
# 0                   You get real help when you need it
# 1    I do not think Alka is neither better nor wors...
# 2    I am so happy for Alka, have received a really...
# 3    Before we could count to 10, we had a new wind...
# 4                   Easy reporting and quick feedback.
# ..                                                 ...
# 977  In connection with a trip that I had to cancel...
# 978  Super professional therapist and everything ra...
# 979  A good insurance company they are fast and eff...
# 980  It was a stone's throw in the windshield, so m...
# 981  Got covered my "injury" to ug, but there was a...
#
#                                           Heading  Rating Location     class  \
# 0                You get real help when you have…       5       DK  positive
# 1                                  I do not think       5       DK  positive
# 2                           I'm so happy for Alka       5       DK  positive
# 3                 Quick, easy and straightforward       5       DK  positive
# 4                        Easy reporting and fast…       5       DK  positive
# ..                                            ...     ...      ...       ...
# 977            In connection with a trip like me…       5       DK  positive
# 978  Super professional therapist and everything…       5       DK  positive
# 979            A good insurance company they are…       5       DK  positive
# 980                    It was a stone's throw in…       4       DK  positive
# 981                       Got my "injury" covered       3       DK   neutral
#
#       gender     day  day_of_year  week_of_year month_year    month  quarter  \
# 0       male  Sunday           16             2    2022-01  January        1
# 1       male  Sunday           16             2    2022-01  January        1
# 2    unknown  Sunday           16             2    2022-01  January        1
# 3       male  Monday           17             3    2022-01  January        1
# 4     female  Monday           17             3    2022-01  January        1
# ..       ...     ...          ...           ...        ...      ...      ...
# 977   female  Sunday          114            16    2022-04    April        2
# 978   female  Sunday          114            16    2022-04    April        2
# 979   female  Sunday          114            16    2022-04    April        2
# 980     male  Sunday          114            16    2022-04    April        2
# 981   female  Sunday          114            16    2022-04    April        2
#
#      year  review_length
# 0    2022             34
# 1    2022            106
# 2    2022             85
# 3    2022            227
# 4    2022             34
# ..    ...            ...
# 977  2022            241
# 978  2022             85
# 979  2022             74
# 980  2022            131
# 981  2022            135
#
# [982 rows x 16 columns]

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Load data

# %%
df = pd.read_pickle('data.pkl')
df
# Out:
#           Date                     Author  \
# 0   2022-01-16          Tonni Kristensen.
# 1   2022-01-16                       inga
# 2   2022-01-17                Susann Taha
# 3   2022-01-17  Michelle Lundberg Badsted
# 4   2022-01-17              Leif Sørensen
# ..         ...                        ...
# 977 2022-04-24             Helle Emmerich
# 978 2022-04-24     Susanne Opperby Madsen
# 979 2022-04-24       Torben Juel Petersen
# 980 2022-04-24        Jan skov Kristensen
# 981 2022-04-24        Sheku  Amadu Jalloh
#
#                                                   Body  \
# 0    I do not think Alka is neither better nor wors...
# 1    I am so happy for Alka, have received a really...
# 2                   Easy reporting and quick feedback.
# 3    Basically, I have received good service and am...
# 4                      Good service and quick response
# ..                                                 ...
# 977  Super professional therapist and everything ra...
# 978  A good insurance company they are fast and eff...
# 979  It was a stone's throw in the windshield, so m...
# 980  Our neighbor is in the process of building a n...
# 981   Alka is always there when they are needed. BRAVO
#
#                                           Heading  Rating Location     class  \
# 0                                  I do not think       5       DK  positive
# 1                           I'm so happy for Alka       5       DK  positive
# 2                        Easy reporting and fast…       5       DK  positive
# 3                           Basically I got good…       4       DK  positive
# 4                                     God service       5       DK  positive
# ..                                            ...     ...      ...       ...
# 977  Super professional therapist and everything…       5       DK  positive
# 978            A good insurance company they are…       5       DK  positive
# 979                    It was a stone's throw in…       4       DK  positive
# 980                Our neighbor is getting built…       2       DK  negative
# 981             Alka is always there when needed…       5       DK  positive
#
#       gender     day  day_of_year  week_of_year month_year    month  quarter  \
# 0       male  Sunday           16             2    2022-01  January        1
# 1    unknown  Sunday           16             2    2022-01  January        1
# 2     female  Monday           17             3    2022-01  January        1
# 3     female  Monday           17             3    2022-01  January        1
# 4       male  Monday           17             3    2022-01  January        1
# ..       ...     ...          ...           ...        ...      ...      ...
# 977   female  Sunday          114            16    2022-04    April        2
# 978   female  Sunday          114            16    2022-04    April        2
# 979     male  Sunday          114            16    2022-04    April        2
# 980     male  Sunday          114            16    2022-04    April        2
# 981  unknown  Sunday          114            16    2022-04    April        2
#
#      year  review_length
# 0    2022            106
# 1    2022             85
# 2    2022             34
# 3    2022            303
# 4    2022             31
# ..    ...            ...
# 977  2022             85
# 978  2022             74
# 979  2022            131
# 980  2022            612
# 981  2022             48
#
# [982 rows x 16 columns]

# %% [markdown]
# ## analysis

# %% [markdown]
# ## Noun Phrase Analysis

# %%
#instantiate spaCy model
model=spacy.load('en_core_web_lg')

#fits model using multi-threadding
df['spaCy_doc'] = [i for i in tq.tqdm(model.pipe(df['Body'], batch_size=10000,n_threads=60))]
# Out:
# 0it [00:00, ?it/s]

# %%
#gets spaCy sentences
df['spaCy_sentences'] = df['spaCy_doc'].map(lambda x:[sent for sent in x.sents])

# %%
#gets spaCy noun chunks
df['spaCy_noun_chunk'] =  df['spaCy_sentences'].map(lambda x: [(token.root.text,token.text) for i in x for token in i.noun_chunks])

# %% [markdown]
# ## Vader

# %%
def getSentiment(df,title_col,review_col):
    
    """This function uses Vader to analyse sentiment of title and review.
    Positive, neutral, negative and compound scores are added to the DataFrame
    """ 

    #Instantiate instance of Vader sentiment model
    analyser = SentimentIntensityAnalyzer()

    #define columns and source columns
    sentiment_cols = [(('title_pos','title_neu','title_neg','title_com'),title_col),
                      (('review_pos','review_neu','review_neg','review_com'),review_col)]

    #loop through columns
    for i in range(len(sentiment_cols)):

        #loop through pos,neu,neg,compound
        for col in range(len(sentiment_cols[i][:-1])):

            #get positive sentiment score
            df[sentiment_cols[i][col][0]] = df[sentiment_cols[i][-1]].map(lambda x: analyser.polarity_scores(x)['pos'])
        
            #get neutral sentiment score
            df[sentiment_cols[i][col][1]] = df[sentiment_cols[i][-1]].map(lambda x: analyser.polarity_scores(x)['neu'])
            
            #get negative sentiment score  
            df[sentiment_cols[i][col][2]] = df[sentiment_cols[i][-1]].map(lambda x: analyser.polarity_scores(x)['neg'])
            
            #get compound sentiment score
            df[sentiment_cols[i][col][3]] = df[sentiment_cols[i][-1]].map(lambda x: analyser.polarity_scores(x)['compound'])

    #return DataFrame
    return df

# %% [markdown]
# # interesting words

# %%
#call getSentiment function on title and review columns
df['Body'].fillna("",inplace=True)
df['Heading'].fillna("",inplace=True)
df = getSentiment(df,'Heading','Body')
df = df.explode(['spaCy_noun_chunk']).explode('spaCy_noun_chunk')
df['count'] =df.groupby('spaCy_noun_chunk')['spaCy_noun_chunk'].transform('count')

# %%
df['spaCy_noun_chunk'].fillna("",inplace=True)

# %%
good = ['website','service','insurance','Alka','treatment','help','employee','company','experience','damage','staff','they','conversation','money','phone']
bad  = ['house','car','company','customer','damage','service','DKK','time','price','information','injury','phone','offer','review','email','Alka','they']

# %%
neg=df[df['class']=='negative'].sort_values(by=['count'],ascending=False)
fig2 =px.treemap(neg[neg['spaCy_noun_chunk'].isin(bad)],path=['spaCy_noun_chunk','Heading','Body'],values='count')

# %%
pos=df[df['class']=='positive'].sort_values(by=['count'],ascending=False)
fig =px.treemap(pos[pos['spaCy_noun_chunk'].isin(good)],path=['spaCy_noun_chunk','Heading','Body'],values='count')

# %%
fig2.write_html("negative.html")

# %% [markdown]
# # descriptive stats

# %%
df = pd.read_pickle('data.pkl')
df
# Out:
#            Date                            Author  \
# 0    2018-01-10  Jonathan Feodor Danstrup Karlsen
# 1    2018-01-10                              Anne
# 2    2018-01-11                      Joan Brøgger
# 3    2018-01-11                           Mirwais
# 4    2018-01-11                   Margit  Kolding
# ...         ...                               ...
# 7672 2022-04-25                     Rikke Nielsen
# 7673 2022-04-25                    Marina Winther
# 7674 2022-04-25                    janni andersen
# 7675 2022-04-25                             klant
# 7676 2022-04-25                     Lene Andersen
#
#                                                    Body  \
# 0     Everything is simply so good! They helped me a...
# 1                             Easy and at a good price.
# 2     Quick and easy operation. However, the origina...
# 3     Lovely easy, fast and transparent it will not ...
# 4     Always get a good treatment and answers to the...
# ...                                                 ...
# 7672                      Quick solution to the problem
# 7673  I sent a review via My Alka on April 20th.\nAt...
# 7674  Really sweet employee and quick response reall...
# 7675  Had to cancel a trip due to Corona, The proces...
# 7676                                  Quick and easy ..
#
#                                               Heading  Rating Location  \
# 0                        Everything is simply so good       5       DK
# 1                            Easy and at a good price       5       DK
# 2                            Quick and easy operation       4       DK
# 3                                           Nice easy       5       DK
# 4                 Always a good treatment and answer…       5       DK
# ...                                               ...     ...      ...
# 7672                    Quick solution to the problem       5       DK
# 7673                            Misleading on My Alka       1       DK
# 7674  Quick response Really sweet employee to talk to       5       DK
# 7675               Had to cancel a trip due to Corona       5       DK
# 7676                                Quick and easy ..       5       DK
#
#          class   gender        day  day_of_year  week_of_year month_year  \
# 0     positive     male  Wednesday           10             2    2018-01
# 1     positive   female  Wednesday           10             2    2018-01
# 2     positive   female   Thursday           11             2    2018-01
# 3     positive  unknown   Thursday           11             2    2018-01
# 4     positive   female   Thursday           11             2    2018-01
# ...        ...      ...        ...          ...           ...        ...
# 7672  positive   female     Monday          115            17    2022-04
# 7673  negative   female     Monday          115            17    2022-04
# 7674  positive  unknown     Monday          115            17    2022-04
# 7675  positive  unknown     Monday          115            17    2022-04
# 7676  positive   female     Monday          115            17    2022-04
#
#         month  quarter  year  review_length
# 0     January        1  2018            178
# 1     January        1  2018             25
# 2     January        1  2018            113
# 3     January        1  2018            162
# 4     January        1  2018             66
# ...       ...      ...   ...            ...
# 7672    April        2  2022             29
# 7673    April        2  2022            690
# 7674    April        2  2022             60
# 7675    April        2  2022            174
# 7676    April        2  2022             17
#
# [7677 rows x 16 columns]

# %%
dfd=df.groupby(['gender'])['gender'].count().to_frame()
fig = px.bar(
    data_frame=dfd,
    y="gender",
).update_layout(
    xaxis_title="Rating", yaxis_title="Count"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c7a1bcb1-e7d1-4d53-809d-0c158adc8555" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7a1bcb1-e7d1-4d53-809d-0c158adc8555")) {                    Plotly.newPlot(                        "c7a1bcb1-e7d1-4d53-809d-0c158adc8555",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>gender=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["female","male","unknown"],"xaxis":"x","y":[2873,3484,1320],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth" ...

# %%
df.groupby(['gender','class'])['class'].count().to_frame()
# Out:
#                   class
# gender  class
# female  negative    284
#         neutral      51
#         positive   2538
# male    negative    592
#         neutral      76
#         positive   2816
# unknown negative    203
#         neutral      31
#         positive   1086

# %%
dfd=df.groupby(['Rating'])['Rating'].count().to_frame()

# %%
fig = px.bar(
    data_frame=dfd,
    y="Rating",
).update_layout(
    xaxis_title="Rating", yaxis_title="Count"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="50727d68-8653-4d78-82bd-ee12ac17caf0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50727d68-8653-4d78-82bd-ee12ac17caf0")) {                    Plotly.newPlot(                        "50727d68-8653-4d78-82bd-ee12ac17caf0",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2,3,4,5],"xaxis":"x","y":[884,195,158,736,5704],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks" ...

# %%
d=df.groupby(['Date'])['Rating'].mean().to_frame()

# %%
fig = px.line(
    data_frame=d,
    y="Rating",
).update_layout(
    xaxis_title="date", yaxis_title="avg. rating"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ef97dfea-cb19-44c1-8847-d2dbff01659b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef97dfea-cb19-44c1-8847-d2dbff01659b")) {                    Plotly.newPlot(                        "ef97dfea-cb19-44c1-8847-d2dbff01659b",                        [{"hovertemplate":"Date=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-13T00:00:00","2018-01-14T00:00:00","2018-01-15T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-20T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-27T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-03T00:00:00","2018-02-05T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-17T00:00:00","2018-02-19T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-03T00:00:00","2018-03-04T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-10T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-17T00:00:00","2018-03-18T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-25T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-03-31T00:00:00","2018-04-01T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-07T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-15T00:00:00","2018-04-16T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-21T00:00:00","2018-04-23T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-28T00:00:00","2018-04-29T00:00:00","2018-04-30T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-05T00:00:00","2018-05-07T00:00:00","2018-05-08T00:00:00","2018-05-09T00:00:00","2018-05-10T00:00:00","2018-05-11T00:00:00","2018-05-13T00:00:00","2018-05-14T00:00:00","2018-05-15T00:00:00","2018-05-16T00:00:00","2018-05-17T00:00:00","2018-05-18T00:00:00","2018-05-19T00:00:00","2018-05-21T00:00:00","2018-05-22T00:00:00","2018-05-23T00:00:00","2018-05-24T00:00:00","2018-05-25T00:00:00","2018-05-28T00:00:00","2018-05-29T00:00:00","2018-05-30T00:00:00","2018-05-31T00:00:00","2018-06-01T00:00:00","2018-06-02T00:00:00","2018-06-06T00:00:00","2018-06-07T00:00:00","2018-06-10T00:00:00","2018-06-11T00:00:00","2018-06-13T00:00:00","2018-06-14T00:00:00","2018-06-15T00:00:00","2018-06-16T00:00:00","2018-06-18T00:00:00","2018-06-20T00:00:00","2018-06-21T00:00:00","2018-06-23T00:00:00","2018-06-25T00:00:00","2018-06-26T00:00:00","2018-06-27T00:00:00","2018-06-28T00:00:00","2018-06-29T00:00:00","2018-07-01T00:00:00","2018-07-02T00:00:00","2018-07-03T00:00:00","2018-07-04T00:00:00","2018-07-05T00:00:00","2018-07-06T00:00:00","2018-07-09T00:00:00","2018-07-10T00:00:00","2018-07-11T00:00:00","2018-07-13T00:00:00","2018-07-14T00:00:00","2018-07-15T00:00:00","2018-07-18T00:00:00","2018-07-19T00:00:00","2018-07-20T00:00:00","2018-07-21T00:00:00","2018-07-22T00:00:00","2018-07-23T00:00:00","2018-07-24T00:00:00"," ...
